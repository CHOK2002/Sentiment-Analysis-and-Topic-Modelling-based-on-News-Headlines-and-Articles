# %% [markdown]
# ### Data Exploring

# %%
import pandas as pd

# load the dataset
df = pd.read_csv('cnn_news_articles_final.csv')

# %%
# print firt 5 rows
df.head()
# Out:
#    Index                                             Author  \
# 0    0.0                                 Jacopo Prisco, CNN
# 1    1.0                              Stephanie Bailey, CNN
# 2    2.0  Words by Stephanie Bailey, video by Zahra Jamshed
# 3    3.0                                     Kathryn Vasel
# 4    4.0                    Paul R. La Monica, CNN Business
#
#         Date published  Category    Section  \
# 0  2021-07-15 02:46:59      news      world
# 1  2021-05-12 07:52:09      news      world
# 2  2021-06-16 02:51:30      news       asia
# 3  2022-03-18 14:37:21  business    success
# 4  2022-03-19 11:41:08  business  investing
#
#                                                  Url  \
# 0  https://www.cnn.com/2021/07/14/world/tusimple-...
# 1  https://www.cnn.com/2021/05/12/world/ironhand-...
# 2  https://www.cnn.com/2021/06/15/asia/swarm-robo...
# 3  https://www.cnn.com/2022/03/18/success/pandemi...
# 4  https://www.cnn.com/2022/03/19/investing/march...
#
# ...

# %%
# print last 5 rows
df.tail()
# Out:
#        Index Author Date published  Category Section  \
# 41872    NaN    NaN            NaN  politics     NaN
# 41873    NaN    NaN            NaN  politics     NaN
# 41874    NaN    NaN            NaN  politics     NaN
# 41875    NaN    NaN            NaN  politics     NaN
# 41876    NaN    NaN            NaN     world     NaN
#
#                                                      Url  \
# 41872  https://edition.cnn.com/2023/01/01/politics/mc...
# 41873  https://edition.cnn.com/2023/02/04/politics/ch...
# 41874  https://edition.cnn.com/2023/02/03/politics/us...
# 41875  https://edition.cnn.com/2023/01/25/politics/ch...
# 41876  https://edition.cnn.com/2023/02/15/europe/russ...
#
#                                                 Headline  \
# 41872  McCarthy commits to key concession in call wit...
# 41873  What to know about the suspected Chinese spy b...
# 41874  Why the US hasn't shot down the suspected Chin...
# 41875  Chinese engineer sentenced to 8 years in US pr...
# ...

# %%
# print the dimensions 
df.shape
# Out:
# (41877, 12)

# %%
# print information about each column (data type and non-null values)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41877 entries, 0 to 41876
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Index            37949 non-null  float64
#  1   Author           37949 non-null  object
#  2   Date published   37949 non-null  object
#  3   Category         41877 non-null  object
#  4   Section          37949 non-null  object
#  5   Url              41877 non-null  object
#  6   Headline         41877 non-null  object
#  7   Description      41873 non-null  object
#  8   Keywords         40735 non-null  object
#  9   Second headline  37949 non-null  object
#  10  Article text     41868 non-null  object
#  11  Unnamed: 0       3928 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 3.8+ MB

# %%
# print how many unique counts in each column
df.nunique()
# Out:
# Index              37949
# Author             11744
# Date published     37948
# Category              14
# Section               55
# Url                41877
# Headline           41785
# Description        41751
# Keywords           40623
# Second headline    37881
# Article text       41846
# Unnamed: 0          3928
# dtype: int64

# %%
# print each unique counts of Category column
df['Category'].value_counts()
# Out:
# Category
# news             18077
# sport            15789
# politics          3026
# business          1775
# health            1037
# world              820
# entertainment      557
# us                 317
# opinions           280
# weather            115
# travel              52
# style               16
# cnn                 11
# vr                   5
# Name: count, dtype: int64

# %%
# print each unique counts of Section column
df['Section'].value_counts()
# Out:
# Section
# europe                  10635
# sport                    5639
# football                 4911
# politics                 2461
# us                       2119
# tennis                   2100
# uk                       1856
# golf                     1498
# motorsport               1386
# opinions                  850
# world                     614
# health                    557
# australia                 547
# entertainment             390
# asia                      301
# business                  284
# americas                  217
# tech                      205
# opinion                   188
# africa                    183
# middleeast                148
# weather                   131
# china                     103
# living                     93
# media                      85
# investing                  82
# economy                    64
# success                    41
# perspectives               41
# travel                     38
# ...

# %%
# check for any missing values 
df.isnull().sum()
# Out:
# Index               3928
# Author              3928
# Date published      3928
# Category               0
# Section             3928
# Url                    0
# Headline               0
# Description            4
# Keywords            1142
# Second headline     3928
# Article text           9
# Unnamed: 0         37949
# dtype: int64

# %%
# check for any duplication
print(df.duplicated().sum())

# filter the dataFrame for duplicate rows
duplicate_rows = df[df.duplicated(keep=False)]

# print the duplicate data
print(duplicate_rows)
# Out:
# 0
# Empty DataFrame
# Columns: [Index, Author, Date published, Category, Section, Url, Headline, Description, Keywords, Second headline, Article text, Unnamed: 0]
# Index: []
